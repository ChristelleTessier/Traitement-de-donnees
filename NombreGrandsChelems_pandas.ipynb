# %%
# Module
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
chemin = os.path.join("Donnees","ATP_match_simple.csv")
matchs = pd.read_csv(chemin)
matchs.head()
# Out:
#    Unnamed: 0 tourney_id tourney_name surface  draw_size tourney_level  \
# 0           0  1969-2029       Dublin   Grass       32.0             A
# 1           1  1969-2029       Dublin   Grass       32.0             A
# 2           2  1969-2029       Dublin   Grass       32.0             A
# 3           3  1969-2029       Dublin   Grass       32.0             A
# 4           4  1969-2029       Dublin   Grass       32.0             A
#
#    tourney_date  match_num  winner_id  winner_seed  ... l_1stIn l_1stWon  \
# 0      19690707        270     100011          NaN  ...     NaN      NaN
# 1      19690707        271     100058          NaN  ...     NaN      NaN
# 2      19690707        272     100114          NaN  ...     NaN      NaN
# 3      19690707        273     125672          NaN  ...     NaN      NaN
# 4      19690707        274     100037          NaN  ...     NaN      NaN
#
#   l_2ndWon  l_SvGms l_bpSaved  l_bpFaced  winner_rank  winner_rank_points  \
# ...

# %%
matchs.shape
# Out:
# (194996, 50)

# %%
grand_chelem = matchs[matchs['tourney_level']=='G']
grand_chelem = grand_chelem[grand_chelem['round']=='F']
grand_chelem.head()
# Out:
#       Unnamed: 0 tourney_id     tourney_name surface  draw_size tourney_level  \
# 1294        1294   1969-520    Roland Garros    Clay      128.0             G
# 1421        1421   1969-540        Wimbledon   Grass      128.0             G
# 1548        1548   1969-560          US Open   Grass      128.0             G
# 1595        1595   1969-580  Australian Open   Grass       64.0             G
# 4802        1637   1970-520    Roland Garros    Clay      128.0             G
#
#       tourney_date  match_num  winner_id  winner_seed  ... l_1stIn l_1stWon  \
# 1294      19690528        127     100029          1.0  ...     NaN      NaN
# 1421      19690623        127     100029          1.0  ...     NaN      NaN
# 1548      19690827        300     100029          1.0  ...     NaN      NaN
# 1595      19690120         47     100029          1.0  ...     NaN      NaN
# 4802      19700501        127     100113          7.0  ...     NaN      NaN
#
# ...

# %%
grand_chelem.shape
# Out:
# (227, 50)

# %%
plus_10_victoires = grand_chelem['winner_name'].value_counts().reset_index()
plus_10_victoires = plus_10_victoires[plus_10_victoires['winner_name']>9]
plus_10_victoires = plus_10_victoires.rename(columns={'index': 'Joueur', 'winner_name': 'Nombre'})
plus_10_victoires
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Program Files\Python310\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Program Files\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Program Files\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'winner_name'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.bar(plus_10_victoires['Joueur'], plus_10_victoires['Nombre'])
# Out:
# <BarContainer object of 5 artists>
