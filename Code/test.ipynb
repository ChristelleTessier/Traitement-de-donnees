# %%
import pandas as pd
import os
import sys

# Utiliser le répertoire courant pour Streamlit
base_path = os.getcwd()
code_path = os.path.join(base_path, "Code")

# Ajouter au sys.path
if code_path not in sys.path:
    sys.path.append(code_path)

# Maintenant importer
from classe_joueur import Joueur
from creer_joueur import creer_joueur

# %%
joueur = creer_joueur(nom = 'Nadal', prenom = 'Rafael')
print(joueur.id_joueur)
# Out:
# 104745

# %%
rencontre = joueur.chercher_tournoi_gagne(annee = 2020)

# %%
rencontre
# Out:
#        tourney_id tourney_date   tourney_name tourney_level surface    type
# 182371  2020-M004   2020-02-24       Acapulco             A    Hard  simple
# 182880   2020-520   2020-09-28  Roland Garros             G    Clay  simple

# %%
test = joueur.chercher_parcours_tournoi('2020-520', 'simple')

# %%
test
# Out:
#          winner_name          loser_name winner_ioc loser_ioc  loser_id  \
# 182817  Rafael Nadal      Egor Gerasimov        ESP       BLR    106078
# 182849  Rafael Nadal  Mackenzie Mcdonald        ESP       USA    111456
# 182865  Rafael Nadal   Stefano Travaglia        ESP       ITA    105882
# 182873  Rafael Nadal     Sebastian Korda        ESP       USA    200624
# 182877  Rafael Nadal       Jannik Sinner        ESP       ITA    206173
# 182879  Rafael Nadal   Diego Schwartzman        ESP       ARG    106043
# 182880  Rafael Nadal      Novak Djokovic        ESP       SRB    104925
#
#         winner_rank  loser_rank       round_label  round_priority  \
# 182817          2.0        83.0  128ème de finale               8
# 182849          2.0       236.0   64ème de finale               7
# 182865          2.0        74.0   32ème de finale               6
# 182873          2.0       213.0   16ème de finale               5
# ...

# %%
joueur.chercher_match_adversaire(104925)
# Out:
#        tourney_date                 tourney_name     winner_name  \
# 141988   2006-05-29                Roland Garros    Rafael Nadal
# 144101   2007-03-05         Indian Wells Masters    Rafael Nadal
# 144003   2007-03-19                Miami Masters  Novak Djokovic
# 144294   2007-05-07                 Rome Masters    Rafael Nadal
# 145155   2007-05-28                Roland Garros    Rafael Nadal
# 145313   2007-06-25                    Wimbledon    Rafael Nadal
# 144429   2007-08-05               Canada Masters  Novak Djokovic
# 145633   2007-11-12                  Masters Cup    Rafael Nadal
# 147213   2008-03-13         Indian Wells Masters  Novak Djokovic
# 147354   2008-05-11              Hamburg Masters    Rafael Nadal
# 148241   2008-05-25                Roland Garros    Rafael Nadal
# 146469   2008-06-09                 Queen's Club    Rafael Nadal
# 147581   2008-07-28           Cincinnati Masters  Novak Djokovic
# ...
